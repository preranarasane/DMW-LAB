# %% [markdown]
# ## Cleaning

# %%
import pandas as pd
import seaborn as sns
import glob
import os

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Handling the missing value problem

# %%
missing_value=["N/a","na","np.nan"]

# %%
df=pd.read_csv("train.csv", na_values=missing_value )

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ONE WAY

# %%
#df1=df.dropna()
#df1

# %% [markdown]
# ### SECONDWAY

# %%
#df=df.drop("Age",1)
#df=df.drop("Cabin",1)
#df=df.drop("Embarked",1)

# %%
#df.isnull().sum()

# %% [markdown]
# ### THIRD WAY

# %%
#df.fillna(0)
#df.interpolete() ......applicable if and only if when there is number in that column

# %%
df1=df.fillna(method="ffill")  #df.fillna(method="bfill")

# %%
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.heatmap(df1.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Integration

# %%
files = os.path.join("F*.csv")

# %%
files = glob.glob(files)

# %%
dff = pd.concat(map(pd.read_csv, files), ignore_index=True)
print(dff)
# Out:
#     Sr.no     Name  Roll No Branch     sex
# 0     1.0      Ram     11.0   comp    Male
# 1     2.0     sham     12.0     it  Female
# 2     3.0      nam     13.0   comp    Male
# 3     4.0      kam     14.0     it    Male
# 4     5.0     meet     15.0   comp  Female
# 5     6.0     bhim     16.0     it    Male
# 6     7.0    arjun     17.0   comp  Female
# 7     8.0  krishna     18.0   comp  Female
# 8     9.0    indra     19.0     it  Female
# 9    10.0  devsena     20.0   comp    Male
# 10    NaN      NaN      NaN    NaN     NaN
# 11   21.0    meeta     31.0   Mech    Male
# 12   22.0   neeta      32.0  Civil  Female
# 13   23.0    seeta     33.0   Mech    Male
# 14   24.0     gita     34.0  Civil    Male
# 15   25.0    radha     35.0  Civil  Female
# 16   26.0    shita     36.0   Mech    Male
# 17   27.0     moni     37.0   Mech  Female
# 18   28.0     soni     38.0  Civil  Female
# 19   29.0     toni     39.0  Civil  Female
# 20   30.0     bina     40.0   Mech    Male
# ...

# %% [markdown]
# ## Transformation

# %%
df1.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
dummy = pd.get_dummies(df1['Sex'])

# %%
dummy
# Out:
#      female  male
# 1         1     0
# 3         1     0
# 6         0     1
# 10        1     0
# 11        1     0
# ..      ...   ...
# 871       1     0
# 872       0     1
# 879       1     0
# 887       1     0
# 889       0     1
#
# [183 rows x 2 columns]

# %%
df2= pd.concat((df1,dummy),axis=1)

# %%
df2.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  female  male
# 1       0  PC 17599  71.2833   C85        C       1     0
# 3       0    113803  53.1000  C123        S       1     0
# 6       0     17463  51.8625   E46        S       0     1
# 10      1   PP 9549  16.7000    G6        S       1     0
# ...

# %%
df2=df2.drop(['Sex'],axis = 1)

# %%
df2.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name   Age  SibSp  Parch  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 6                             McCarthy, Mr. Timothy J  54.0      0      0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0      1      1
# 11                           Bonnell, Miss. Elizabeth  58.0      0      0
#
#       Ticket     Fare Cabin Embarked  female  male
# 1   PC 17599  71.2833   C85        C       1     0
# 3     113803  53.1000  C123        S       1     0
# 6      17463  51.8625   E46        S       0     1
# 10   PP 9549  16.7000    G6        S       1     0
# 11    113783  26.5500  C103        S       1     0

# %%
df2=df2.drop(['male'],axis = 1)

# %%
df2=df2.rename(columns={"female":"Sex"})

# %%
df2.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name   Age  SibSp  Parch  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 6                             McCarthy, Mr. Timothy J  54.0      0      0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0      1      1
# 11                           Bonnell, Miss. Elizabeth  58.0      0      0
#
#       Ticket     Fare Cabin Embarked  Sex
# 1   PC 17599  71.2833   C85        C    1
# 3     113803  53.1000  C123        S    1
# 6      17463  51.8625   E46        S    0
# 10   PP 9549  16.7000    G6        S    1
# 11    113783  26.5500  C103        S    1

# %% [markdown]
# ## Reduction

# %%
df2=df2.drop(['Fare'],axis=1)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name   Age  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 6                              McCarthy, Mr. Timothy J  54.0      0      0
# 10                     Sandstrom, Miss. Marguerite Rut   4.0      1      1
# 11                            Bonnell, Miss. Elizabeth  58.0      0      0
# ..                                                 ...   ...    ...    ...
# ...
